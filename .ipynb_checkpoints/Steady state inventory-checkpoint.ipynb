# %%
#Third Year Paper Code
import numpy as np
import random 
import matplotlib.pyplot as plt

# %%
# Simulation Setting
# Based on DO (1999) lab setting
# with u = 100
# start with production good in storage
# constant gain learning with gamma = 0.7

# %%
#Basic Parameters
u = 100
β = 0.9
c_1 = 1
c_2 = 4
c_3 = 9
t = 1
γ = 0.5

# %%
#initial value for Q
#When initial condition is production good in storage
#based on rational expectation
shock = 0
Q_12 = 65 + shock
Q_13 = 103 + shock
Q_11 = Q_12 + u
Q_21 = 256 + shock
Q_23 = 244 + shock
Q_22 = Q_23 + u
Q_31 = 290 + shock
Q_32 = 230 + shock
Q_33 = Q_31 + u

# %%
# Create agents
# Agents have there type which same as there consumption type, they also have production type
class Agent:
    agentCount = 0

    def __init__(self, id, consume_type, product_type):
        self.id = id
        self.consume_type = consume_type
        self.product_type = product_type
        self.storage_type = product_type
        self.opposite_storage = 0
        self.trading_result = False
        self.trading = False
        self.original_storage = self.storage_type

        #generate type 1 agents' Q(precieved value for holding good 1 , 2 , 3)
        if self.consume_type == 1:
            self.Q_2 = 50 + random.randint(1,10)
        if self.consume_type == 1:
            self.Q_3 = 50 + random.randint(1,10)
        if self.consume_type == 1:
            self.Q_1 = 9999
            
        #generate type 2 agents' Q(precieved value for holding good 1 , 2 , 3)
        if self.consume_type == 2:
            self.Q_1 = 256 + random.randint(1,50)
        if self.consume_type == 2:
            self.Q_3 = 244 + random.randint(1,50)
        if self.consume_type == 2:
            self.Q_2 = 9999
            
        #generate type 3 agents' Q(precieved value for holding good 1 , 2 , 3)
        if self.consume_type == 3:
            self.Q_1 = 290 + random.randint(1,80)
        if self.consume_type == 3:
            self.Q_2 = 230 + random.randint(1,80)
        if self.consume_type == 3:
            self.Q_3 = 9999

        # other characteristics wait to be added
        Agent.agentCount += 1

    def displayAgent(self):
        print("Agent id:", self.id, "consume:", self.consume_type, ",produce:", self.product_type, ",storage:",
              self.storage_type, "Q_1:", self.Q_1, "Q_2:", self.Q_2, "Q_3:", self.Q_3,"opposite:",self.opposite_storage,"trading:",self.trading,"trading_reuslt:",self.trading_result)

# %%
# matching process
# update agent's information of what situation he is facing
def match(mylist):
    random.shuffle(mylist)
    matchlist = dict()
    index = list(range(0, len(mylist), 2))
    for i in index:
        matchlist[mylist[i]] = mylist[i + 1]
    for key in matchlist:
        update_opposite_storage(key,matchlist[key]) 
        key.original_storage = key.storage_type #easy to update Q at the end of the round
        matchlist[key].original_storage = matchlist[key].storage_type
    return matchlist

# update what good the other agent is holding
def update_opposite_storage(agent1, agent2):
    storage_1 = agent1.storage_type
    storage_2 = agent2.storage_type
    agent1.opposite_storage = storage_2
    agent2.opposite_storage = storage_1

# %%
#get the parameters for decision making and updating Q
def get_Q_hold(agent):
    if agent.storage_type == 1:
        return agent.Q_1
    elif agent.storage_type == 2:
        return agent.Q_2
    elif agent.storage_type == 3:
        return agent.Q_3

def get_original_Q_hold(agent):
    if agent.original_storage == 1:
        return agent.Q_1
    elif agent.original_storage == 2:
        return agent.Q_2
    elif agent.original_storage == 3:
        return agent.Q_3

def set_Q_hold(agent,update_value):
    if agent.storage_type == 1:
        agent.Q_1 = update_value
    elif agent.storage_type == 2:
        agent.Q_2 = update_value
    elif agent.storage_type == 3:
        agent.Q_3 = update_value
        
def set_original_Q_hold(agent,update_value):
    if agent.original_storage == 1:
        agent.Q_1 = update_value
    elif agent.original_storage == 2:
        agent.Q_2 = update_value
    elif agent.original_storage == 3:
        agent.Q_3 = update_value

def get_Q_trade(agent):
    if agent.opposite_storage == 1:
        return agent.Q_1
    elif agent.opposite_storage == 2:
        return agent.Q_2
    elif agent.opposite_storage == 3:
        return agent.Q_3

def get_C_hold(agent):
    if agent.storage_type == 1:
        return c_1
    elif agent.storage_type == 2:
        return c_2
    elif agent.storage_type == 3:
        return c_3

def get_C_trade(agent):
    if agent.opposite_storage == 1:
        return c_1
    elif agent.opposite_storage == 2:
        return c_2
    elif agent.opposite_storage == 3:
        return c_3

# %%
# trading decision by each agent
def transaction_decision(agent):
    Q_hold = get_Q_hold(agent)
    Q_trade = get_Q_trade(agent)
    C_hold = get_C_hold(agent)
    C_trade = get_C_trade(agent)

    if β * Q_hold - C_hold < β * Q_trade - C_trade:
        agent.trading = True
    else:
        agent.trading = False
        
# trading results 
def produce_outcome(matched_list):
    trade_outcome = list()
    for key in matched_list.keys():
        if key.trading == True and matched_list[key].trading == True:
            trade_outcome.append(True)
            key.trading_result = True
            matched_list[key].trading_result = True
        else:
            trade_outcome.append(False)
            key.trading_result = False
            matched_list[key].trading_result = False
    return trade_outcome

# %%
# based on trading result, updates Q and storage

def update_trading(agent):
    if(agent.trading_result == False): #if there is trade
        v_prime = get_C_hold(agent)*(-1) + β * get_Q_hold(agent)
        updated_value = get_Q_hold(agent) + γ * (v_prime - get_Q_hold(agent))
        set_Q_hold(agent,updated_value)
    else: #if trade happened 
        if agent.consume_type == agent.opposite_storage: #agent gets his own consumption good
            agent.storage_type = agent.product_type #agent eats the consumption good and produces another production good 
            v_prime = get_C_hold(agent) * (-1) + β * get_Q_hold(agent) + u
            updated_value = get_original_Q_hold(agent) + γ * (v_prime - get_original_Q_hold(agent))
            set_original_Q_hold(agent,updated_value)
        else: #agent does not get his cons good
            agent.storage_type = agent.opposite_storage 
            v_prime = get_C_hold(agent) *(-1) + β * get_Q_hold(agent)
            updated_value = get_original_Q_hold(agent) + γ * (v_prime - get_original_Q_hold(agent))
            set_original_Q_hold(agent, updated_value)

# %%
# Global behavior recorder

def global_a1_s2_f3(mylist,count_down,count_up): #agent 1 holding 2 facing opportunity for 3
    result = list()
    for ele in mylist:
        if (ele.consume_type == 1 and ele.storage_type == 2 and ele.opposite_storage == 3):
            count_down += 1
            if (ele.trading == True):
                count_up += 1

    result.append(count_up)
    result.append(count_down)
    return result

def global_a2_s3_f1(mylist,count_down,count_up): #agent 2 holding 3 facing opportunity for 1
    result = list()
    for ele in mylist:
        if (ele.consume_type == 2 and ele.storage_type == 3 and ele.opposite_storage == 1):
            count_down += 1
            if (ele.trading == True):
                count_up += 1

    result.append(count_up)
    result.append(count_down)
    return result

def global_a3_s1_f2(mylist,count_down,count_up): #agent 3 holding 1 facing opportunity for 2
    result = list()
    for ele in mylist:
        if (ele.consume_type == 3 and ele.storage_type == 1 and ele.opposite_storage == 2):
            count_down += 1
            if (ele.trading == True):
                count_up += 1

    result.append(count_up)
    result.append(count_down)
    return result

def global_a1_s_f1(mylist,count_down,count_up): #agent 1 holding ANY good facing opportunity for 1
    result = list()
    for ele in mylist:
        if (ele.consume_type == 1  and ele.opposite_storage == 1):
            count_down += 1
            if (ele.trading == True):
                count_up += 1

    result.append(count_up)
    result.append(count_down)
    return result

def global_a2_s_f2(mylist,count_down,count_up): #agent 2 holding ANY good facing opportunity for 2
    result = list()
    for ele in mylist:
        if (ele.consume_type == 2  and ele.opposite_storage ==2 ):
            count_down += 1
            if (ele.trading == True):
                count_up += 1

    result.append(count_up)
    result.append(count_down)
    return result

def global_a3_s_f3(mylist,count_down,count_up): #agent 3 holding ANY good facing opportunity for 3
    result = list()
    for ele in mylist:
        if (ele.consume_type == 3  and ele.opposite_storage ==3 ):
            count_down += 1
            if (ele.trading == True):
                count_up += 1

    result.append(count_up)
    result.append(count_down)
    return result

# %%
# main code

if __name__ == '__main__':
    u = 100
    β = 0.9
    c_1 = 1
    c_2 = 4
    c_3 = 9
    t = 1

    mylist = list()
    agent1 = Agent(1, 1, 2)
    mylist.append(agent1)
    agent2 = Agent(2, 1, 2)
    mylist.append(agent2)
    agent3 = Agent(3, 1, 2)
    mylist.append(agent3)
    agent4 = Agent(4, 1, 2)
    mylist.append(agent4)
    agent5 = Agent(5, 1, 2)
    mylist.append(agent5)
    agent6 = Agent(6, 1, 2)
    mylist.append(agent6)
    agent7 = Agent(7, 1, 3)
    mylist.append(agent7)
    agent8 = Agent(8, 1, 3)
    mylist.append(agent8)
    agent9 = Agent(9, 2, 3)
    mylist.append(agent9)
    agent10 = Agent(10, 2, 3)
    mylist.append(agent10)
    agent11 = Agent(11, 2, 3)
    mylist.append(agent11)
    agent12 = Agent(12, 2, 3)
    mylist.append(agent12)
    agent13 = Agent(13, 2, 3)
    mylist.append(agent13)
    agent14 = Agent(14, 2, 1)
    mylist.append(agent14)
    agent15 = Agent(15, 2, 1)
    mylist.append(agent15)
    agent16 = Agent(16, 2, 1)
    mylist.append(agent16)
    agent17 = Agent(17, 3, 1)
    mylist.append(agent17)
    agent18 = Agent(18, 3, 1)
    mylist.append(agent18)
    agent19 = Agent(19, 3, 1)
    mylist.append(agent19)
    agent20 = Agent(20, 3, 1)
    mylist.append(agent20)
    agent21 = Agent(21, 3, 1)
    mylist.append(agent21)
    agent22 = Agent(22, 3, 1)
    mylist.append(agent22)
    agent23 = Agent(23, 3, 1)
    mylist.append(agent23)
    agent24 = Agent(24, 3, 1)
    mylist.append(agent24)

    game_continue = True

    count_round = 0
    sum_up123 = 0
    sum_down123 = 0
    sum_up231 = 0
    sum_down231 = 0
    sum_up312 = 0
    sum_down312 = 0
    
    result_list_123_each_round = []
    result_list_123_sum = []
    result_list_231_each_round = []
    result_list_231_sum = []
    result_list_312_each_round = []
    result_list_312_sum = []
    
    
    sum_up11 = 0
    sum_down11 = 0
    sum_up22 = 0
    sum_down22 = 0
    sum_up33 = 0
    sum_down33 = 0
    
    t_list = []
    
    while(count_round < 140):
        count_round += 1
        t_list.append(count_round)
        matched_list = match(mylist)

        for key in matched_list.keys():
            transaction_decision(key)
            transaction_decision(matched_list[key])

        global_r1_2_3 = global_a1_s2_f3(mylist,0,0)
        sum_up123 = sum_up123 + global_r1_2_3[0]
        sum_down123 = sum_down123 + global_r1_2_3[1]
        result_list_123_each_round.append( (global_r1_2_3[0]+0.1) / (global_r1_2_3[1]+0.1) )
        result_list_123_sum.append((sum_up123+0.1)/(sum_down123+0.1))
        
        global_r2_3_1 = global_a2_s3_f1(mylist,0,0)
        sum_up231 = sum_up231 + global_r2_3_1[0]
        sum_down231 = sum_down231 + global_r2_3_1[1]
        result_list_231_each_round.append( (global_r2_3_1[0]+0.1) / (global_r2_3_1[1]+0.1) )
        result_list_231_sum.append((sum_up231+0.1)/(sum_down231+0.1))
        
        global_r3_1_2 = global_a3_s1_f2(mylist,0,0)
        sum_up312 = sum_up312 + global_r3_1_2[0]
        sum_down312 = sum_down312 + global_r3_1_2[1]
        result_list_312_each_round.append( (global_r3_1_2[0]+0.1) / (global_r3_1_2[1]+0.1) )
        result_list_312_sum.append((sum_up312+0.1)/(sum_down312+0.1))
        
        global_r1_1 = global_a1_s_f1(mylist,0,0)
        sum_up11 = sum_up11 + global_r1_1[0]
        sum_down11 = sum_down11 + global_r1_1[1]
        
        global_r2_2 = global_a2_s_f2(mylist,0,0)
        sum_up22 = sum_up22 + global_r2_2[0]
        sum_down22 = sum_down22 + global_r2_2[1]
        
        global_r3_3 = global_a3_s_f3(mylist,0,0)
        sum_up33 = sum_up33 + global_r3_3[0]
        sum_down33 = sum_down33 + global_r3_3[1]
        
        

        for ele in mylist:
            ele.displayAgent()

        produce_outcome(matched_list)

        for key in matched_list.keys():
            update_trading(key)
            update_trading(matched_list[key])

        print(count_round)

        stopping_draw = random.uniform(0, 1)
        if stopping_draw > 0.01:
            game_continue = True
        else:
            game_continue = False

    print("Agent 1 with good 2 facing good 3:", sum_up123/sum_down123)
    print("Agent 2 with good 3 facing good 1:", sum_up231/sum_down231)
    print("Agent 3 with good 1 facing good 2:", sum_up312/sum_down312)
    
    print("Agent 1 facing good 1:", sum_up11/sum_down11)
    print("Agent 2 facing good 2:", sum_up22/sum_down22)
    print("Agent 3 facing good 3:", sum_up33/sum_down33)
# Out:
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 294 Q_2: 303 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 3 Q_1: 257 Q_2: 9999 Q_3: 258 opposite: 1 trading: True trading_reuslt: False
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 60 Q_3: 63 opposite: 3 trading: False trading_reuslt: False
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 62 opposite: 2 trading: True trading_reuslt: False
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 54 opposite: 1 trading: True trading_reuslt: False
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 1 Q_1: 355 Q_2: 308 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 263 Q_2: 9999 Q_3: 288 opposite: 1 trading: False trading_reuslt: False
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 1 Q_1: 322 Q_2: 287 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 263 Q_2: 9999 Q_3: 279 opposite: 2 trading: True trading_reuslt: False
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 53 Q_3: 65 opposite: 1 trading: True trading_reuslt: False
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 311 Q_2: 285 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 351 Q_2: 310 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 3 Q_1: 280 Q_2: 9999 Q_3: 247 opposite: 1 trading: True trading_reuslt: False
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 301 Q_2: 242 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 344 Q_2: 310 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 3 Q_1: 258 Q_2: 9999 Q_3: 292 opposite: 1 trading: False trading_reuslt: False
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 3 Q_1: 293 Q_2: 9999 Q_3: 277 opposite: 1 trading: True trading_reuslt: False
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 368 Q_2: 303 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 3 Q_1: 268 Q_2: 9999 Q_3: 293 opposite: 2 trading: True trading_reuslt: False
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 61 Q_3: 60 opposite: 3 trading: False trading_reuslt: False
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 59 Q_3: 67 opposite: 2 trading: False trading_reuslt: False
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 68 Q_3: 57 opposite: 2 trading: False trading_reuslt: False
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 276 Q_2: 9999 Q_3: 255 opposite: 2 trading: True trading_reuslt: False
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 66 Q_3: 51 opposite: 1 trading: True trading_reuslt: False
# 1
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 62.6 Q_3: 57 opposite: 1 trading: True trading_reuslt: False
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 335.45000000000005 Q_2: 242 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 1 Q_1: 280 Q_2: 9999 Q_3: 249.0 opposite: 1 trading: False trading_reuslt: True
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 1 Q_1: 386.75 Q_2: 308 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 110.7 Q_3: 51 opposite: 1 trading: True trading_reuslt: True
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 1 Q_1: 257 Q_2: 9999 Q_3: 244.15 opposite: 2 trading: True trading_reuslt: True
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 299.35 Q_2: 9999 Q_3: 279 opposite: 2 trading: True trading_reuslt: True
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 98.35 Q_3: 65 opposite: 1 trading: True trading_reuslt: True
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 55.0 Q_3: 63 opposite: 1 trading: True trading_reuslt: False
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 311.7 Q_2: 9999 Q_3: 255 opposite: 2 trading: True trading_reuslt: True
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 3 Q_1: 268 Q_2: 9999 Q_3: 273.85 opposite: 1 trading: True trading_reuslt: False
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 332.95000000000005 Q_2: 310 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 249.35000000000002 Q_2: 9999 Q_3: 288 opposite: 1 trading: False trading_reuslt: False
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 326.3 Q_2: 310 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 54.05 Q_3: 67 opposite: 1 trading: True trading_reuslt: False
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 1 Q_1: 305.4 Q_2: 287 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 328.8 Q_2: 303 Q_3: 9999 opposite: 3 trading: True trading_reuslt: True
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 96.8 opposite: 1 trading: True trading_reuslt: True
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 294.95000000000005 Q_2: 285 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 54.400000000000006 opposite: 1 trading: True trading_reuslt: False
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 3 Q_1: 258 Q_2: 9999 Q_3: 272.9 opposite: 1 trading: False trading_reuslt: False
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 1 Q_1: 293 Q_2: 9999 Q_3: 269.85 opposite: 3 trading: False trading_reuslt: True
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 55.95 Q_3: 60 opposite: 1 trading: True trading_reuslt: False
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 399.1 Q_2: 303 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# 2
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 378.64500000000004 Q_2: 303 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 329.70250000000004 Q_2: 285 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 236.38250000000002 Q_2: 9999 Q_3: 288 opposite: 1 trading: False trading_reuslt: False
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 1 Q_1: 366.9125 Q_2: 308 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 1 Q_1: 289.63 Q_2: 287 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 309.485 Q_2: 310 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 361.86 Q_2: 303 Q_3: 9999 opposite: 3 trading: True trading_reuslt: True
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 3 Q_1: 258 Q_2: 9999 Q_3: 254.755 opposite: 1 trading: True trading_reuslt: False
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 137.46 opposite: 1 trading: True trading_reuslt: True
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 345.615 Q_2: 9999 Q_3: 255 opposite: 3 trading: False trading_reuslt: True
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 97.18 opposite: 1 trading: True trading_reuslt: True
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 318.1775 Q_2: 242 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 1 Q_1: 265.5 Q_2: 9999 Q_3: 249.0 opposite: 2 trading: True trading_reuslt: False
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 153.165 Q_3: 51 opposite: 1 trading: True trading_reuslt: True
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 365.8025 Q_2: 310 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 100.25 Q_3: 63 opposite: 1 trading: True trading_reuslt: True
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 3 Q_1: 283.8675 Q_2: 9999 Q_3: 244.15 opposite: 1 trading: True trading_reuslt: True
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 1 Q_1: 277.85 Q_2: 9999 Q_3: 269.85 opposite: 3 trading: False trading_reuslt: False
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 49.3475 Q_3: 67 opposite: 1 trading: True trading_reuslt: False
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 1 Q_1: 268 Q_2: 9999 Q_3: 257.02500000000003 opposite: 2 trading: True trading_reuslt: True
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 141.4325 Q_3: 65 opposite: 1 trading: True trading_reuslt: True
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 333.88250000000005 Q_2: 9999 Q_3: 279 opposite: 2 trading: True trading_reuslt: True
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 57.47 Q_3: 57 opposite: 2 trading: False trading_reuslt: False
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 51.1525 Q_3: 60 opposite: 2 trading: False trading_reuslt: False
# 3
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 126.08700000000002 opposite: 1 trading: True trading_reuslt: False
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 351.76862500000004 Q_2: 242 Q_3: 9999 opposite: 3 trading: True trading_reuslt: True
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 93.23750000000001 Q_3: 63 opposite: 2 trading: False trading_reuslt: False
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 52.5965 Q_3: 57 opposite: 2 trading: False trading_reuslt: False
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 327.83425 Q_2: 9999 Q_3: 255 opposite: 3 trading: False trading_reuslt: False
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 3 Q_1: 295.16125 Q_2: 9999 Q_3: 257.02500000000003 opposite: 1 trading: True trading_reuslt: True
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 1 Q_1: 348.06687500000004 Q_2: 308 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 1 Q_1: 263.45750000000004 Q_2: 9999 Q_3: 269.85 opposite: 1 trading: False trading_reuslt: False
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 1 Q_1: 274.6485 Q_2: 287 Q_3: 9999 opposite: 2 trading: True trading_reuslt: False
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 193.50675 Q_3: 51 opposite: 1 trading: True trading_reuslt: True
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 182.36087500000002 Q_3: 65 opposite: 1 trading: True trading_reuslt: True
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 393.26700000000005 Q_2: 303 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 137.821 opposite: 1 trading: True trading_reuslt: True
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 347.012375 Q_2: 310 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 94.88012499999999 Q_3: 67 opposite: 1 trading: True trading_reuslt: True
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 359.21275 Q_2: 303 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 3 Q_1: 283.8675 Q_2: 9999 Q_3: 227.4425 opposite: 1 trading: True trading_reuslt: False
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 293.51075000000003 Q_2: 310 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 224.063375 Q_2: 9999 Q_3: 288 opposite: 1 trading: False trading_reuslt: False
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 1 Q_1: 258 Q_2: 9999 Q_3: 242.97750000000002 opposite: 1 trading: False trading_reuslt: True
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 3 Q_1: 290.3 Q_2: 9999 Q_3: 249.0 opposite: 1 trading: True trading_reuslt: True
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 312.71737500000006 Q_2: 285 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 366.68837500000006 Q_2: 9999 Q_3: 279 opposite: 2 trading: True trading_reuslt: True
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 46.594875 Q_3: 60 opposite: 1 trading: True trading_reuslt: False
# 4
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 212.36020625 Q_2: 9999 Q_3: 288 opposite: 1 trading: False trading_reuslt: False
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 346.5815062500001 Q_2: 285 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 1 Q_1: 244.60000000000002 Q_2: 9999 Q_3: 242.97750000000002 opposite: 1 trading: False trading_reuslt: False
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 340.75211250000007 Q_2: 303 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 47.966674999999995 Q_3: 57 opposite: 2 trading: False trading_reuslt: False
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 92.26513125 Q_3: 60 opposite: 2 trading: False trading_reuslt: True
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 231.8314125 Q_3: 51 opposite: 2 trading: False trading_reuslt: True
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 2 Q_1: 264.47425 Q_2: 287 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 373.10365 Q_2: 303 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 383.68019375000006 Q_2: 242 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 310.9425375 Q_2: 9999 Q_3: 255 opposite: 2 trading: True trading_reuslt: False
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 86.575625 Q_3: 63 opposite: 1 trading: True trading_reuslt: False
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 1 Q_1: 330.16353125 Q_2: 308 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 165.28265000000002 opposite: 1 trading: True trading_reuslt: True
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 379.16175625000005 Q_2: 310 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 328.3352125 Q_2: 310 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 1 Q_1: 249.78462500000003 Q_2: 9999 Q_3: 269.85 opposite: 1 trading: False trading_reuslt: False
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 397.85395625000007 Q_2: 9999 Q_3: 279 opposite: 1 trading: False trading_reuslt: True
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 88.13611875 Q_3: 67 opposite: 1 trading: True trading_reuslt: False
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 1 Q_1: 290.3 Q_2: 9999 Q_3: 254.63500000000002 opposite: 2 trading: True trading_reuslt: True
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 176.42995000000002 opposite: 3 trading: False trading_reuslt: True
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 3 Q_1: 295.16125 Q_2: 9999 Q_3: 239.67375000000004 opposite: 3 trading: False trading_reuslt: False
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 171.24283125000002 Q_3: 65 opposite: 1 trading: True trading_reuslt: False
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 1 Q_1: 283.8675 Q_2: 9999 Q_3: 240.961625 opposite: 2 trading: True trading_reuslt: True
# 5
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 311.418451875 Q_2: 310 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 344.895410625 Q_2: 9999 Q_3: 255 opposite: 1 trading: False trading_reuslt: True
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1:
ading_reuslt: False
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.4853506781788 Q_2: 147.96132233669022 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 308.84708623290595 Q_3: 51 opposite: 2 trading: False trading_reuslt: True
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 156.3553687918319 Q_2: 139.567817839132 Q_3: 9999 opposite: 3 trading: True trading_reuslt: True
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 90.08270103469374 opposite: 1 trading: True trading_reuslt: False
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 240.45215401880458 Q_2: 150.4182988224262 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.85981648622305 Q_2: 161.2469055259666 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 264.94550067246234 opposite: 1 trading: True trading_reuslt: False
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 264.44112315558203 Q_2: 166.94594011900136 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 256.8646870359959 Q_2: 9999 Q_3: 129.4939567995333 opposite: 3 trading: False trading_reuslt: True
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 3 Q_1: 215.6479245121402 Q_2: 9999 Q_3: 177.3307204932063 opposite: 1 trading: True trading_reuslt: False
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 1 Q_1: 229.69065530417356 Q_2: 9999 Q_3: 214.3290315735394 opposite: 1 trading: False trading_reuslt: False
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 1 Q_1: 178.38988085351866 Q_2: 9999 Q_3: 141.5824496585649 opposite: 1 trading: False trading_reuslt: False
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 3 Q_1: 210.13519461124457 Q_2: 9999 Q_3: 140.41282023319565 opposite: 2 trading: True trading_reuslt: True
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 2 Q_1: 196.97869163741055 Q_2: 102.04376224810665 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# 137
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 343.9924662744777 Q_2: 9999 Q_3: 227.3097266973013 opposite: 3 trading: False trading_reuslt: True
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 131.07856598295905 opposite: 1 trading: True trading_reuslt: True
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 223.33117518382508 Q_2: 205.53801916777124 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 196.97869163741055 Q_2: 189.16229236088807 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 264.0562779936222 Q_2: 9999 Q_3: 206.66844529530673 opposite: 2 trading: True trading_reuslt: True
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.85981648622305 Q_2: 151.18456024966827 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 262.17193874005125 Q_3: 65 opposite: 1 trading: True trading_reuslt: False
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 227.92954631786435 Q_2: 150.4182988224262 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 243.52145268419613 Q_2: 9999 Q_3: 129.4939567995333 opposite: 2 trading: True trading_reuslt: False
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 352.4880491032827 Q_3: 60 opposite: 1 trading: True trading_reuslt: True
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 186.31494362662465 Q_2: 92.58254635915404 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 1 Q_1: 168.97038681084274 Q_2: 9999 Q_3: 141.5824496585649 opposite: 1 trading: False trading_reuslt: False
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 291.4047319212607 Q_3: 51 opposite: 2 trading: False trading_reuslt: False
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.4853506781788 Q_2: 138.5632562198557 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 3 Q_1: 195.33723877106814 Q_2: 9999 Q_3: 190.43762870975786 opposite: 2 trading: True trading_reuslt: False
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 213.86921922038272 Q_3: 122.79979642773604 opposite: 3 trading: False trading_reuslt: True
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 242.58706903801493 Q_3: 63 opposite: 1 trading: True trading_reuslt: False
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 198.0376003522403 Q_2: 139.567817839132 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 3 Q_1: 215.6479245121402 Q_2: 9999 Q_3: 163.96418446854597 opposite: 3 trading: False trading_reuslt: False
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 297.19822563883923 opposite: 3 trading: False trading_reuslt: True
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 300.71906699780294 Q_2: 166.94594011900136 Q_3: 9999 opposite: 3 trading: True trading_reuslt: True
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 3 Q_1: 210.13519461124457 Q_2: 9999 Q_3: 178.89217922153586 opposite: 1 trading: True trading_reuslt: True
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 1 Q_1: 217.7061225389649 Q_2: 9999 Q_3: 214.3290315735394 opposite: 2 trading: True trading_reuslt: False
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 110.5943279700027 Q_3: 67 opposite: 1 trading: True trading_reuslt: False
# 138
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 3 Q_1: 215.6479245121402 Q_2: 9999 Q_3: 151.26597524511868 opposite: 3 trading: False trading_reuslt: False
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 3 Q_1: 195.33723877106814 Q_2: 9999 Q_3: 176.41574727426996 opposite: 3 trading: False trading_reuslt: False
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 201.1757582593636 Q_3: 122.79979642773604 opposite: 2 trading: False trading_reuslt: False
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 153.06461157150255 Q_3: 67 opposite: 2 trading: False trading_reuslt: True
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 187.63572033462827 Q_2: 139.567817839132 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 3 Q_1: 250.80112547757517 Q_2: 9999 Q_3: 214.3290315735394 opposite: 1 trading: True trading_reuslt: True
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.85981648622305 Q_2: 141.62533223718486 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 176.49919644529342 Q_2: 92.58254635915404 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 277.8383143568973 opposite: 1 trading: True trading_reuslt: False
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 211.66461642463383 Q_2: 205.53801916777124 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 250.35346409394108 Q_2: 9999 Q_3: 206.66844529530673 opposite: 2 trading: True trading_reuslt: False
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 382.86364664811856 Q_3: 60 opposite: 1 trading: True trading_reuslt: True
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 228.4577155861142 Q_3: 63 opposite: 1 trading: True trading_reuslt: False
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 1 Q_1: 160.0218674703006 Q_2: 9999 Q_3: 141.5824496585649 opposite: 2 trading: True trading_reuslt: False
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 120.02463768381111 opposite: 2 trading: False trading_reuslt: False
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 247.06334180304867 Q_3: 65 opposite: 3 trading: False trading_reuslt: False
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 186.62975705554004 Q_2: 189.16229236088807 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 274.8344953251976 Q_3: 51 opposite: 1 trading: True trading_reuslt: False
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 280.8453800499863 Q_2: 9999 Q_3: 129.4939567995333 opposite: 1 trading: False trading_reuslt: True
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 326.2928429607538 Q_2: 9999 Q_3: 227.3097266973013 opposite: 1 trading: False trading_reuslt: False
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.4853506781788 Q_2: 129.63509340886293 Q_3: 9999 opposite: 1 trading: True trading_reuslt: False
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 335.1831136479128 Q_2: 166.94594011900136 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 1 Q_1: 210.13519461124457 Q_2: 9999 Q_3: 183.50692718582798 opposite: 1 trading: False trading_reuslt: True
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 216.0330690019711 Q_2: 150.4182988224262 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# 139
# Agent id: 22 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.4853506781788 Q_2: 121.15333873841979 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 10 consume: 2 ,produce: 3 ,storage: 3 Q_1: 189.22303608150452 Q_2: 9999 Q_3: 141.5824496585649 opposite: 2 trading: True trading_reuslt: True
# Agent id: 5 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 411.72046431571266 Q_3: 60 opposite: 1 trading: True trading_reuslt: True
# Agent id: 14 consume: 2 ,produce: 1 ,storage: 1 Q_1: 287.33579088924404 Q_2: 9999 Q_3: 206.66844529530673 opposite: 2 trading: True trading_reuslt: True
# Agent id: 8 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 62 Q_3: 109.52340579962055 opposite: 1 trading: True trading_reuslt: False
# Agent id: 16 consume: 2 ,produce: 1 ,storage: 1 Q_1: 309.47820081271607 Q_2: 9999 Q_3: 227.3097266973013 opposite: 3 trading: False trading_reuslt: False
# Agent id: 11 consume: 2 ,produce: 3 ,storage: 3 Q_1: 195.33723877106814 Q_2: 9999 Q_3: 163.09495991055647 opposite: 1 trading: True trading_reuslt: False
# Agent id: 17 consume: 3 ,produce: 1 ,storage: 1 Q_1: 176.79826920276304 Q_2: 189.16229236088807 Q_3: 9999 opposite: 3 trading: True trading_reuslt: False
# Agent id: 13 consume: 2 ,produce: 3 ,storage: 1 Q_1: 250.80112547757517 Q_2: 9999 Q_3: 219.52502225167854 opposite: 1 trading: False trading_reuslt: True
# Agent id: 19 consume: 3 ,produce: 1 ,storage: 1 Q_1: 317.92395796551716 Q_2: 166.94594011900136 Q_3: 9999 opposite: 1 trading: False trading_reuslt: False
# Agent id: 3 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 259.09277055893773 Q_3: 51 opposite: 1 trading: True trading_reuslt: False
# Agent id: 21 consume: 3 ,produce: 1 ,storage: 1 Q_1: 204.73141555187254 Q_2: 150.4182988224262 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 15 consume: 2 ,produce: 1 ,storage: 1 Q_1: 266.303111047487 Q_2: 9999 Q_3: 129.4939567995333 opposite: 3 trading: False trading_reuslt: False
# Agent id: 12 consume: 2 ,produce: 3 ,storage: 3 Q_1: 215.6479245121402 Q_2: 9999 Q_3: 139.20267648286276 opposite: 1 trading: True trading_reuslt: False
# Agent id: 20 consume: 3 ,produce: 1 ,storage: 1 Q_1: 227.75393431789686 Q_2: 139.567817839132 Q_3: 9999 opposite: 2 trading: False trading_reuslt: True
# Agent id: 23 consume: 3 ,produce: 1 ,storage: 2 Q_1: 133.85981648622305 Q_2: 132.54406562532563 Q_3: 9999 opposite: 1 trading: True trading_reuslt: False
# Agent id: 6 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 189.11697034639542 Q_3: 122.79979642773604 opposite: 2 trading: False trading_reuslt: False
# Agent id: 2 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 265.0348298068085 Q_3: 63 opposite: 2 trading: False trading_reuslt: True
# Agent id: 1 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 143.41138099292743 Q_3: 67 opposite: 1 trading: True trading_reuslt: False
# Agent id: 18 consume: 3 ,produce: 1 ,storage: 1 Q_1: 167.17423662302875 Q_2: 92.58254635915404 Q_3: 9999 opposite: 2 trading: False trading_reuslt: False
# Agent id: 9 consume: 2 ,produce: 3 ,storage: 1 Q_1: 199.12843488068233 Q_2: 9999 Q_3: 183.50692718582798 opposite: 1 trading: False trading_reuslt: False
# Agent id: 24 consume: 3 ,produce: 1 ,storage: 1 Q_1: 250.58138560340214 Q_2: 205.53801916777124 Q_3: 9999 opposite: 1 trading: False trading_reuslt: True
# Agent id: 4 consume: 1 ,produce: 2 ,storage: 2 Q_1: 9999 Q_2: 232.71017471289625 Q_3: 65 opposite: 3 trading: False trading_reuslt: False
# Agent id: 7 consume: 1 ,produce: 3 ,storage: 3 Q_1: 9999 Q_2: 57 Q_3: 309.4463986390524 opposite: 2 trading: False trading_reuslt: True
# 140
# Agent 1 with good 2 facing good 3: 0.03048780487804878
# Agent 2 with good 3 facing good 1: 0.8854166666666666
# Agent 3 with good 1 facing good 2: 0.22743682310469315
# Agent 1 facing good 1: 1.0
# Agent 2 facing good 2: 1.0
# Agent 3 facing good 3: 1.0

# %%
#plot the dynamic of the behavior

#plt.plot(result_list_123_each_round)
plt.plot(result_list_123_sum, label = "agent1")
#plt.plot(result_list_123_each_round)
plt.plot(result_list_231_sum, label = "agent2")
#plt.plot(result_list_123_each_round)
plt.plot(result_list_312_sum, label = "agent3")
plt.legend()
plt.xlabel("t")
plt.ylabel("Percentage")
plt.show()

# %%
#plt the best responds of the behavior
plt.plot(result_list_123_sum, label = "agent1")
plt.legend()
plt.xlabel("t")
plt.ylabel("Percentage")
plt.show()

# %%
br_312 = result_list_312_sum
for i in range(len(br_312)):
    br_312[i] = 1 - br_312[i]

# %%
#best respond graph
plt.plot(result_list_123_sum, label = "agent1")
plt.plot(result_list_231_sum, label = "agent2")
plt.plot(br_312, label = "agent3")
plt.legend()
plt.xlabel("t")
plt.ylabel("Percentage")
plt.show()
